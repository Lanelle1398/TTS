# %%
#load sql
# %load_ext sql

# %%
#Connect to SQLite database
# %sql sqlite://

# %%
# %sql sqlite:////Users/lanellephillips/Downloads/my_ipod.sqlite3

# %% [markdown]
# 1. SELECT everything from a table

# %%
# %sql select * from songs
# Out:
#    sqlite://
#  * sqlite:////Users/lanellephillips/Downloads/my_ipod.sqlite3
# Done.
# [(1, 'All I Really Want', '4:45', 1, '2018-03-31 14:25:38.774208', '2018-03-31 14:25:38.774208'),
#  (2, 'You Oughta Know', '4:09', 1, '2018-03-31 14:25:38.785592', '2018-03-31 14:25:38.785592'),
#  (3, 'Perfect', '3:08', 1, '2018-03-31 14:25:38.794810', '2018-03-31 14:25:38.794810'),
#  (4, 'Hand in My Pocket', '3:42', 1, '2018-03-31 14:25:38.809997', '2018-03-31 14:25:38.809997'),
#  (5, 'Right Through You', '2:56', 1, '2018-03-31 14:25:38.817045', '2018-03-31 14:25:38.817045'),
#  (6, 'Forgiven', '5:00', 1, '2018-03-31 14:25:38.822645', '2018-03-31 14:25:38.822645'),
#  (7, 'You Learn', '4:00', 1, '2018-03-31 14:25:38.836672', '2018-03-31 14:25:38.836672'),
#  (8, 'Head over Feet', '4:27', 1, '2018-03-31 14:25:38.860589', '2018-03-31 14:25:38.860589'),
#  (9, 'Mary Jane', '4:41', 1, '2018-03-31 14:25:38.871126', '2018-03-31 14:25:38.871126'),
# ...

# %% [markdown]
# 2. SELECT exactly one column from a table. SELECT more than one but not all columns from a table

# %%
# %sql SELECT name from songs
# Out:
#    sqlite://
#  * sqlite:////Users/lanellephillips/Downloads/my_ipod.sqlite3
# Done.
# [('All I Really Want',),
#  ('You Oughta Know',),
#  ('Perfect',),
#  ('Hand in My Pocket',),
#  ('Right Through You',),
#  ('Forgiven',),
#  ('You Learn',),
#  ('Head over Feet',),
#  ('Mary Jane',),
#  ('Ironic',),
#  ('Not the Doctor',),
#  ('Wake Up',),
#  ('You Oughta Know (Jimmy the Saint Blend) / Your House (a cappella) (Hidden track)',),
#  ('Losing Grip',),
#  ('Complicated',),
#  ('Sk8er Boi',),
#  ("I'm With You",),
#  ('Dangerous Woman',),
#  ('Side to Side',),
#  ('Everyday (ft. Future)',),
#  ('Thinking Bout You',),
#  ('Highway to Hell',),
#  ('Girls Got Rhythm',),
#  ('Walk All Over You',),
#  ('Shot Down in Flames',),
#  ('Hold On',),
#  ('I Found You',),
#  ('Hang Loose',),
#  ('Rise To The Sun',),
#  ("You Ain't Alone",),
#  ('I And Love And You',),
#  ('January Wedding',),
#  ('Heart Full Of Doubt',),
#  ('And It Spread',),
#  ('War Pigs',),
#  ('Paranoid',),
# ...

# %%
# %sql SELECT name,length from songs
# Out:
#    sqlite://
#  * sqlite:////Users/lanellephillips/Downloads/my_ipod.sqlite3
# Done.
# [('All I Really Want', '4:45'),
#  ('You Oughta Know', '4:09'),
#  ('Perfect', '3:08'),
#  ('Hand in My Pocket', '3:42'),
#  ('Right Through You', '2:56'),
#  ('Forgiven', '5:00'),
#  ('You Learn', '4:00'),
#  ('Head over Feet', '4:27'),
#  ('Mary Jane', '4:41'),
#  ('Ironic', '3:50'),
#  ('Not the Doctor', '3:48'),
#  ('Wake Up', '4:54'),
#  ('You Oughta Know (Jimmy the Saint Blend) / Your House (a cappella) (Hidden track)', '8:13'),
#  ('Losing Grip', '3:54'),
#  ('Complicated', '4:05'),
#  ('Sk8er Boi', '3:24'),
#  ("I'm With You", '3:44'),
#  ('Dangerous Woman', '3:56'),
#  ('Side to Side', '3:46'),
#  ('Everyday (ft. Future)', '3:15'),
#  ('Thinking Bout You', '3:20'),
#  ('Highway to Hell', '3:28'),
#  ('Girls Got Rhythm', '3:24'),
#  ('Walk All Over You', '5:09'),
#  ('Shot Down in Flames', '3:23'),
#  ('Hold On', '3:46'),
#  ('I Found You', '3:00'),
#  ('Hang Loose', '2:24'),
# ...

# %% [markdown]
# 3. SELECT everything from the songs table whose id numbers are even and greater than 50, or odd and less than ten.

# %%
# %sql select * from songs WHERE (((id%2=1) AND (id<10)) OR ((id%2=0) AND (id>50)))
# Out:
#    sqlite://
#  * sqlite:////Users/lanellephillips/Downloads/my_ipod.sqlite3
# Done.
# [(1, 'All I Really Want', '4:45', 1, '2018-03-31 14:25:38.774208', '2018-03-31 14:25:38.774208'),
#  (3, 'Perfect', '3:08', 1, '2018-03-31 14:25:38.794810', '2018-03-31 14:25:38.794810'),
#  (5, 'Right Through You', '2:56', 1, '2018-03-31 14:25:38.817045', '2018-03-31 14:25:38.817045'),
#  (7, 'You Learn', '4:00', 1, '2018-03-31 14:25:38.836672', '2018-03-31 14:25:38.836672'),
#  (9, 'Mary Jane', '4:41', 1, '2018-03-31 14:25:38.871126', '2018-03-31 14:25:38.871126'),
#  (52, 'Holocene', '5:37', 11, '2018-03-31 14:25:39.444264', '2018-03-31 14:25:39.444264'),
#  (54, 'Respect', '2:28', 12, '2018-03-31 14:25:39.480152', '2018-03-31 14:25:39.480152'),
#  (56, 'Save Me', '2:22', 12, '2018-03-31 14:25:39.509158', '2018-03-31 14:25:39.509158'),
#  (58, 'Graduation Day', '1:22', 13, '2018-03-31 14:25:39.530274', '2018-03-31 14:25:39.530274'),
# ...

# %% [markdown]
# 4. INSERT ten new records into the User table. They can be real or fictional individuals.

# %%
# %%sql
# CREATE TABLE User67
# (
#     UserID INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL,
#     FirstName VARCHAR(50) ,
#     LastName VARCHAR(50) ,
#     Birthplace VARCHAR(50),
#     CreatedAt DATETIME NOT NULL,
#     UpdatedAt DATETIME NULL
# );
#
# INSERT INTO User67 VALUES(1220, 'Lanel', 'Phillips', 'Greece','2010-11-11', NULL);
# INSERT INTO User67 VALUES(1230, 'Lanel', 'Phil', 'Haiti','2010-11-12', NULL);
# INSERT INTO User67 VALUES(1240, 'Layna', 'Paul', 'Sudan','2013-11-11', NULL );
# INSERT INTO User67 VALUES(1250, 'Lelsie', 'Philly', 'Greenland','2013-12-11', NULL );
# INSERT INTO User67 VALUES(1260, 'Lanie', 'Ph', 'Grenada','2014-11-11', NULL);
# INSERT INTO User67 VALUES(1270, 'Lanella', 'Phill', 'Guyana','2016-11-11', NULL );
# INSERT INTO User67 VALUES(1280, 'Lan', 'Phillip', 'Barbados','2018-11-11', NULL );
# INSERT INTO User67 VALUES(1290, 'Lucy', 'Phyl', 'Italy','2019-11-11', NULL);
# INSERT INTO User67 VALUES(1300, 'Lacy', 'Philli', 'Paris','2019-12-11', NULL );
# Out:
#    sqlite://
#  * sqlite:////Users/lanellephillips/Downloads/my_ipod.sqlite3
# Done.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# []

# %%
# %%sql
# INSERT INTO User67 VALUES(1200, 'Lashley', 'Paulina', 'Cameroon','2010-06-11', NULL);
# Out:
#    sqlite://
#  * sqlite:////Users/lanellephillips/Downloads/my_ipod.sqlite3
# 1 rows affected.
# []

# %%
# %sql select * from User67
# Out:
#    sqlite://
#  * sqlite:////Users/lanellephillips/Downloads/my_ipod.sqlite3
# Done.
# [(1200, 'Lashley', 'Paulina', 'Cameroon', '2010-06-11', None),
#  (1220, 'Lanel', 'Phillips', 'Greece', '2010-11-11', None),
#  (1230, 'Lanel', 'Phil', 'Haiti', '2010-11-12', None),
#  (1240, 'Layna', 'Paul', 'Sudan', '2013-11-11', None),
#  (1250, 'Lelsie', 'Philly', 'Greenland', '2013-12-11', None),
#  (1260, 'Lanie', 'Ph', 'Grenada', '2014-11-11', None),
#  (1270, 'Lanella', 'Phill', 'Guyana', '2016-11-11', None),
#  (1280, 'Lanayla', 'Phillip', 'Barbados', '2018-11-11', None),
#  (1290, 'Lanelle', 'Phyl', 'Italy', '2019-11-11', None),
#  (1300, 'Layla', 'Philli', 'Paris', '2019-12-11', '2022-09-27 20:45:26')]

# %% [markdown]
# Below is a duplicate table(ignore)

# %%
# %%sql
# CREATE TABLE User68
# (
#     UserID INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL,
#     FirstName VARCHAR(50) ,
#     LastName VARCHAR(50) ,
#     Birthplace VARCHAR(50),
#     CreatedAt DATETIME NOT NULL,
#     UpdatedAt DATETIME NULL
# );
#
# INSERT INTO User68 VALUES(1220, 'Lanel', 'Phillips', 'Greece','2010-11-11', NULL);
# INSERT INTO User68 VALUES(1230, 'Lanel', 'Phil', 'Haiti','2010-11-12', NULL);
# INSERT INTO User68 VALUES(1240, 'Layna', 'Paul', 'Sudan','2013-11-11', NULL );
# INSERT INTO User68 VALUES(1250, 'Lelsie', 'Philly', 'Greenland','2013-12-11', NULL );
# INSERT INTO User68 VALUES(1260, 'Lanie', 'Ph', 'Grenada','2014-11-11', NULL);
# INSERT INTO User68 VALUES(1270, 'Lanella', 'Phill', 'Guyana','2016-11-11', NULL );
# INSERT INTO User68 VALUES(1280, 'Lan', 'Phillip', 'Barbados','2018-11-11', NULL );
# INSERT INTO User68 VALUES(1290, 'Lucy', 'Phyl', 'Italy','2019-11-11', NULL);
# INSERT INTO User68 VALUES(1300, 'Lacy', 'Philli', 'Paris','2019-12-11', NULL );
# Out:
#    sqlite://
#  * sqlite:////Users/lanellephillips/Downloads/my_ipod.sqlite3
# Done.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# []

# %% [markdown]
# 5. UPDATE the User table and change some names. When you UPDATE, do not forget to put CURRENT_TIMESTAMP into UpdatedAt. That way, you always know when the last update was.

# %%
# %%sql
# UPDATE User67
# SET FirstName = 'Lelsyianna', UpdatedAT = CURRENT_TIMESTAMP
# WHERE UserID=1290;
# Out:
#    sqlite://
#  * sqlite:////Users/lanellephillips/Downloads/my_ipod.sqlite3
# 1 rows affected.
# []

# %%
# %%sql
# UPDATE User67
# SET FirstName = 'Leich', UpdatedAT = CURRENT_TIMESTAMP
# WHERE UserID=1300;
# Out:
#    sqlite://
#  * sqlite:////Users/lanellephillips/Downloads/my_ipod.sqlite3
# 1 rows affected.
# []

# %%
# %sql select * from User67
# Out:
#    sqlite://
#  * sqlite:////Users/lanellephillips/Downloads/my_ipod.sqlite3
# Done.
# [(1200, 'Lashley', 'Paulina', 'Cameroon', '2010-06-11', None),
#  (1220, 'Lanel', 'Phillips', 'Greece', '2010-11-11', None),
#  (1230, 'Lanel', 'Phil', 'Haiti', '2010-11-12', None),
#  (1240, 'Layna', 'Paul', 'Sudan', '2013-11-11', None),
#  (1250, 'Lelsie', 'Philly', 'Greenland', '2013-12-11', None),
#  (1260, 'Lanie', 'Ph', 'Grenada', '2014-11-11', None),
#  (1270, 'Lanella', 'Phill', 'Guyana', '2016-11-11', None),
#  (1280, 'Lanayla', 'Phillip', 'Barbados', '2018-11-11', None),
#  (1290, 'Lelsyianna', 'Phyl', 'Italy', '2019-11-11', '2022-09-27 21:07:45'),
#  (1300, 'Leich', 'Philli', 'Paris', '2019-12-11', '2022-09-27 21:08:29')]

# %% [markdown]
# 6. Use a TRANSACTION/ROLLBACK window to DELETE everything from the User table.
#
#    See screenshots

# %% [markdown]
# 7. For each user in the User table, add a record to the Favorite table, but only INSERT for UserID (the FK), and CreatedAt.

# %%
# %%sql
# CREATE TABLE Favorite5
# (
#     FavoriteID INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL,
#     UserID INTEGER NOT NULL,
#     ArtistID INTEGER,
#     AlbumID INTEGER,
#     SongID INTEGER,
#     GenreID INTEGER,
#     CreatedAt DATETIME NOT NULL,
#     UpdatedAt DATETIME NULL,
#     FOREIGN KEY (UserID) REFERENCES User (UserID)
#
# );
#
# INSERT INTO Favorite5 VALUES(23, 1220, 513, 245, 456,556,'2010-11-11', NULL);
# Out:
#    sqlite://
#  * sqlite:////Users/lanellephillips/Downloads/my_ipod.sqlite3
# Done.
# 1 rows affected.
# []

# %%
# %%sql
# INSERT INTO Favorite5 (FavoriteID) VALUES (24);
# INSERT INTO Favorite5 (UserID) VALUES (1230);
# INSERT INTO Favorite5 (CreatedAt) VALUES ('2010-11-12');

# %%
# %sql select * from Favorite5
# Out:
#    sqlite://
#  * sqlite:////Users/lanellephillips/Downloads/my_ipod.sqlite3
# Done.
# [(23, 1220, 513, 245, 456, 556, '2010-11-11', None)]

# %% [markdown]
# 8. Use a TRANSACTION/ROLLBACK window to DELETE everything from the Favorite table WHERE the FavoriteID is odd, or even but greater than 10
#
#     See screenshots

# %% [markdown]
# 9.Put "SELECT * FROM Favorite;" in the window to make sure you delete only those records you should!
#
#     See screenshots
